# %% [markdown]
# ### add population

# %%
import pandas as pd
import numpy as np

# %%
df_from = pd.read_csv("C:\\HANSSAK\\SecureGate\\Download\\[09] 세계지도.csv", encoding='cp949')
df_to = pd.read_csv("C:\\HANSSAK\\SecureGate\\Download\\출입국자_지도_국가코드_6대륙.csv", encoding='cp949')

# %%
df_from[df_from['NAT_NM']=="대한민국"]
# Out:
#     code NAT_NM     lng     lat  POP_CT_1000_UNIT_CNT  IMGRT_CNT
# 27     0   대한민국  128.16  36.338                 51269       1728

# %%
mapping = df_from.set_index('NAT_NM')['POP_CT_1000_UNIT_CNT']
df_to['POP_CT_1000_UNIT_CNT'] = df_to['NAT_HAN_NM'].map(mapping)
# Out:
#      code NAT_HAN_NM       lng      lat    CNT     대륙 CONTINENT  \
# 0     646         홍콩  114.0599  22.4114    996    아시아      ASIA
# 1     412        헝가리   19.6180  47.1740  49946     유럽    EUROPE
# 2       0         한국  128.1600  36.3380   2190    아시아      ASIA
# 3     611        필리핀  121.2560  17.1810      0    아시아      ASIA
# 4     430        핀란드   26.1920  62.7160   2270     유럽    EUROPE
# ..    ...        ...       ...      ...    ...    ...       ...
# 216     0       과들루프  -61.5527  16.2495      0  북아메리카       NaN
# 217   546        감비아  -14.6410  13.4990      0   아프리카    AFRICA
# 218   205       가이아나  -58.9390   5.1700      0  남아메리카        SA
# 219   537         가봉   11.9140  -0.4060      0   아프리카    AFRICA
# 220   525         가나   -1.0620   7.2580      0   아프리카    AFRICA
#
#      POP_CT_1000_UNIT_CNT
# 0                  7497.0
# 1                  9660.0
# 2                     NaN
# 3                109581.0
# 4                  5541.0
# ..                    ...
# ...

# %%
df_to[df_to['POP_CT_1000_UNIT_CNT'].isna()]
# Out:
#      code   NAT_HAN_NM       lng      lat    CNT     대륙 CONTINENT  \
# 2       0           한국  128.1600  36.3380   2190    아시아      ASIA
# 12      0          팔라우  134.5573   7.5288      0  오세아니아   OCEANIA
# 17      0     티모르민주공화국  125.5560  -8.8560      0    아시아      ASIA
# 21      0          투발루  178.6758  -7.4786      0  오세아니아   OCEANIA
# 25      0      터크스케이커스  -71.7592  21.7779    432  북아메리카       NaN
# 28    614          타이완  120.8353  23.6091    500    아시아      ASIA
# 29    605           타이  100.8450  15.6880      0    아시아      ASIA
# 30    642         키프로스   32.9280  34.8940    514     유럽    EUROPE
# 35      0        쿡아일랜드 -159.8200 -21.2020      0  오세아니아   OCEANIA
# 38    548      콩고민주공화국   23.6070  -1.4180      0   아프리카    AFRICA
# 39    536           콩고   16.0800   0.5090      0   아프리카    AFRICA
# 44      0        케이맨제도  -81.1715  19.3299      0  북아메리카       NaN
# 54      0           차트   18.7810  15.9810     14   아프리카    AFRICA
# ...

# %%
df_to.to_csv("C:\\HANSSAK\\SecureGate\\Download\\출입국자_지도_국가코드_6대륙_인구수.csv", encoding='cp949', index=False)
